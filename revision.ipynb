# %% [markdown]
# <a href="https://colab.research.google.com/github/hengcc918-creator/revision-journal/blob/main/revision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub! This is a revision on GitHub.")
# Out:
# Hello, GitHub! This is a revision on GitHub.
